# %%
# Install TensorFlow for  Google Colab
# !pip install -q tensorflow-gpu==2.0.0-beta1 # needed in Colab

try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass
# Out:
#      |████████████████████████████████| 348.9MB 39kB/s
#      |████████████████████████████████| 501kB 40.0MB/s
#      |████████████████████████████████| 3.1MB 45.7MB/s
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.
# 2.1.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer # sample data
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %%
# load the data
data = load_breast_cancer()
print(type(data)) #data is a bunch, acts like a dictionary 
print(data.keys())
# Out:
# <class 'sklearn.utils.Bunch'>
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
# targets 
##data.target - binary classification 
##data.target_names - description of the binary class, not useful for learning 
# Features 

data.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
# let's see what are we dealing with
data.data.shape
# Out:
# (569, 30)

# %% [markdown]
# Prepare the data

# %%
# Create test and train sets 
X_train, X_test, y_train, y_test = train_test_split(data.data, 
                                                    data.target, 
                                                    test_size=0.33)
N, D = X_train.shape

# Scale the data - fundamental for certain type of models. 

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Build the Model

# %%
# Now all the fun Tensorflow stuff
# Build the model

model = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(D,)),
  tf.keras.layers.Dense(1, activation='sigmoid') # binary classification hence 1
])

# Alternatively, you can do:
# model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.Dense(1, input_shape=(D,), activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])


# Train the model
r = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100)


# Evaluate the model - evaluate() returns loss and accuracy
print(f"Train score:{model.evaluate(X_train, y_train)}" )
print(f"Test score: {model.evaluate(X_test, y_test)}", )
# Out:
# Train on 381 samples, validate on 188 samples
# Epoch 1/100
# 381/381 [==============================] - 0s 940us/sample - loss: 1.2034 - accuracy: 0.1732 - val_loss: 1.1354 - val_accuracy: 0.2074
# Epoch 2/100
# 381/381 [==============================] - 0s 87us/sample - loss: 1.0978 - accuracy: 0.2231 - val_loss: 1.0264 - val_accuracy: 0.2606
# Epoch 3/100
# 381/381 [==============================] - 0s 85us/sample - loss: 1.0001 - accuracy: 0.2782 - val_loss: 0.9265 - val_accuracy: 0.3032
# Epoch 4/100
# 381/381 [==============================] - 0s 80us/sample - loss: 0.9135 - accuracy: 0.3307 - val_loss: 0.8367 - val_accuracy: 0.3564
# Epoch 5/100
# 381/381 [==============================] - 0s 87us/sample - loss: 0.8322 - accuracy: 0.4042 - val_loss: 0.7609 - val_accuracy: 0.4894
# Epoch 6/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.7653 - accuracy: 0.4541 - val_loss: 0.6933 - val_accuracy: 0.5798
# Epoch 7/100
# 381/381 [==============================] - 0s 79us/sample - loss: 0.7036 - accuracy: 0.5643 - val_loss: 0.6373 - val_accuracy: 0.6862
# Epoch 8/100
# 381/381 [==============================] - 0s 83us/sample - loss: 0.6516 - accuracy: 0.6168 - val_loss: 0.5882 - val_accuracy: 0.7340
# Epoch 9/100
# 381/381 [==============================] - 0s 84us/sample - loss: 0.6071 - accuracy: 0.6903 - val_loss: 0.5458 - val_accuracy: 0.7713
# Epoch 10/100
# 381/381 [==============================] - 0s 86us/sample - loss: 0.5666 - accuracy: 0.7323 - val_loss: 0.5097 - val_accuracy: 0.7872
# Epoch 11/100
# 381/381 [==============================] - 0s 81us/sample - loss: 0.5324 - accuracy: 0.7795 - val_loss: 0.4786 - val_accuracy: 0.8138
# Epoch 12/100
# 381/381 [==============================] - 0s 90us/sample - loss: 0.5019 - accuracy: 0.8136 - val_loss: 0.4509 - val_accuracy: 0.8351
# Epoch 13/100
# 381/381 [==============================] - 0s 81us/sample - loss: 0.4751 - accuracy: 0.8451 - val_loss: 0.4266 - val_accuracy: 0.8404
# Epoch 14/100
# 381/381 [==============================] - 0s 96us/sample - loss: 0.4511 - accuracy: 0.8530 - val_loss: 0.4051 - val_accuracy: 0.8511
# Epoch 15/100
# 381/381 [==============================] - 0s 84us/sample - loss: 0.4293 - accuracy: 0.8609 - val_loss: 0.3858 - val_accuracy: 0.8670
# Epoch 16/100
# 381/381 [==============================] - 0s 80us/sample - loss: 0.4102 - accuracy: 0.8688 - val_loss: 0.3685 - val_accuracy: 0.8830
# Epoch 17/100
# 381/381 [==============================] - 0s 73us/sample - loss: 0.3929 - accuracy: 0.8793 - val_loss: 0.3525 - val_accuracy: 0.8883
# Epoch 18/100
# 381/381 [==============================] - 0s 88us/sample - loss: 0.3767 - accuracy: 0.8845 - val_loss: 0.3383 - val_accuracy: 0.8936
# Epoch 19/100
# 381/381 [==============================] - 0s 80us/sample - loss: 0.3623 - accuracy: 0.8871 - val_loss: 0.3250 - val_accuracy: 0.8989
# Epoch 20/100
# 381/381 [==============================] - 0s 85us/sample - loss: 0.3489 - accuracy: 0.8976 - val_loss: 0.3133 - val_accuracy: 0.9096
# Epoch 21/100
# 381/381 [==============================] - 0s 83us/sample - loss: 0.3370 - accuracy: 0.9029 - val_loss: 0.3021 - val_accuracy: 0.9202
# Epoch 22/100
# 381/381 [==============================] - 0s 86us/sample - loss: 0.3254 - accuracy: 0.9029 - val_loss: 0.2920 - val_accuracy: 0.9255
# Epoch 23/100
# 381/381 [==============================] - 0s 80us/sample - loss: 0.3150 - accuracy: 0.9081 - val_loss: 0.2827 - val_accuracy: 0.9255
# Epoch 24/100
# 381/381 [==============================] - 0s 89us/sample - loss: 0.3055 - accuracy: 0.9108 - val_loss: 0.2738 - val_accuracy: 0.9255
# Epoch 25/100
# 381/381 [==============================] - 0s 84us/sample - loss: 0.2965 - accuracy: 0.9108 - val_loss: 0.2658 - val_accuracy: 0.9309
# Epoch 26/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.2882 - accuracy: 0.9186 - val_loss: 0.2583 - val_accuracy: 0.9362
# Epoch 27/100
# 381/381 [==============================] - 0s 89us/sample - loss: 0.2804 - accuracy: 0.9213 - val_loss: 0.2513 - val_accuracy: 0.9362
# Epoch 28/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.2731 - accuracy: 0.9239 - val_loss: 0.2447 - val_accuracy: 0.9362
# Epoch 29/100
# 381/381 [==============================] - 0s 84us/sample - loss: 0.2664 - accuracy: 0.9291 - val_loss: 0.2384 - val_accuracy: 0.9362
# Epoch 30/100
# 381/381 [==============================] - 0s 86us/sample - loss: 0.2599 - accuracy: 0.9291 - val_loss: 0.2325 - val_accuracy: 0.9415
# Epoch 31/100
# 381/381 [==============================] - 0s 92us/sample - loss: 0.2537 - accuracy: 0.9291 - val_loss: 0.2272 - val_accuracy: 0.9415
# Epoch 32/100
# 381/381 [==============================] - 0s 92us/sample - loss: 0.2481 - accuracy: 0.9318 - val_loss: 0.2220 - val_accuracy: 0.9415
# Epoch 33/100
# 381/381 [==============================] - 0s 80us/sample - loss: 0.2428 - accuracy: 0.9318 - val_loss: 0.2171 - val_accuracy: 0.9415
# Epoch 34/100
# 381/381 [==============================] - 0s 80us/sample - loss: 0.2376 - accuracy: 0.9344 - val_loss: 0.2125 - val_accuracy: 0.9415
# Epoch 35/100
# 381/381 [==============================] - 0s 80us/sample - loss: 0.2328 - accuracy: 0.9370 - val_loss: 0.2081 - val_accuracy: 0.9415
# Epoch 36/100
# 381/381 [==============================] - 0s 84us/sample - loss: 0.2283 - accuracy: 0.9370 - val_loss: 0.2038 - val_accuracy: 0.9415
# Epoch 37/100
# 381/381 [==============================] - 0s 85us/sample - loss: 0.2238 - accuracy: 0.9396 - val_loss: 0.2000 - val_accuracy: 0.9415
# Epoch 38/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.2197 - accuracy: 0.9396 - val_loss: 0.1962 - val_accuracy: 0.9415
# Epoch 39/100
# 381/381 [==============================] - 0s 86us/sample - loss: 0.2159 - accuracy: 0.9396 - val_loss: 0.1927 - val_accuracy: 0.9415
# Epoch 40/100
# 381/381 [==============================] - 0s 101us/sample - loss: 0.2120 - accuracy: 0.9423 - val_loss: 0.1892 - val_accuracy: 0.9468
# Epoch 41/100
# 381/381 [==============================] - 0s 114us/sample - loss: 0.2084 - accuracy: 0.9423 - val_loss: 0.1859 - val_accuracy: 0.9468
# Epoch 42/100
# 381/381 [==============================] - 0s 81us/sample - loss: 0.2050 - accuracy: 0.9449 - val_loss: 0.1828 - val_accuracy: 0.9468
# Epoch 43/100
# 381/381 [==============================] - 0s 87us/sample - loss: 0.2017 - accuracy: 0.9475 - val_loss: 0.1798 - val_accuracy: 0.9468
# Epoch 44/100
# 381/381 [==============================] - 0s 84us/sample - loss: 0.1986 - accuracy: 0.9475 - val_loss: 0.1769 - val_accuracy: 0.9468
# Epoch 45/100
# 381/381 [==============================] - 0s 79us/sample - loss: 0.1955 - accuracy: 0.9501 - val_loss: 0.1742 - val_accuracy: 0.9468
# Epoch 46/100
# 381/381 [==============================] - 0s 87us/sample - loss: 0.1926 - accuracy: 0.9501 - val_loss: 0.1716 - val_accuracy: 0.9468
# Epoch 47/100
# 381/381 [==============================] - 0s 84us/sample - loss: 0.1899 - accuracy: 0.9501 - val_loss: 0.1691 - val_accuracy: 0.9468
# Epoch 48/100
# 381/381 [==============================] - 0s 80us/sample - loss: 0.1871 - accuracy: 0.9501 - val_loss: 0.1667 - val_accuracy: 0.9468
# Epoch 49/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.1846 - accuracy: 0.9501 - val_loss: 0.1644 - val_accuracy: 0.9468
# Epoch 50/100
# 381/381 [==============================] - 0s 87us/sample - loss: 0.1821 - accuracy: 0.9501 - val_loss: 0.1622 - val_accuracy: 0.9468
# Epoch 51/100
# 381/381 [==============================] - 0s 85us/sample - loss: 0.1797 - accuracy: 0.9528 - val_loss: 0.1600 - val_accuracy: 0.9468
# Epoch 52/100
# 381/381 [==============================] - 0s 90us/sample - loss: 0.1773 - accuracy: 0.9528 - val_loss: 0.1579 - val_accuracy: 0.9468
# Epoch 53/100
# 381/381 [==============================] - 0s 83us/sample - loss: 0.1751 - accuracy: 0.9554 - val_loss: 0.1559 - val_accuracy: 0.9468
# Epoch 54/100
# 381/381 [==============================] - 0s 86us/sample - loss: 0.1730 - accuracy: 0.9580 - val_loss: 0.1540 - val_accuracy: 0.9521
# Epoch 55/100
# 381/381 [==============================] - 0s 86us/sample - loss: 0.1709 - accuracy: 0.9606 - val_loss: 0.1522 - val_accuracy: 0.9521
# Epoch 56/100
# 381/381 [==============================] - 0s 81us/sample - loss: 0.1689 - accuracy: 0.9606 - val_loss: 0.1504 - val_accuracy: 0.9521
# Epoch 57/100
# 381/381 [==============================] - 0s 92us/sample - loss: 0.1669 - accuracy: 0.9606 - val_loss: 0.1486 - val_accuracy: 0.9574
# Epoch 58/100
# 381/381 [==============================] - 0s 103us/sample - loss: 0.1650 - accuracy: 0.9633 - val_loss: 0.1469 - val_accuracy: 0.9628
# Epoch 59/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.1632 - accuracy: 0.9633 - val_loss: 0.1454 - val_accuracy: 0.9628
# Epoch 60/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.1615 - accuracy: 0.9633 - val_loss: 0.1438 - val_accuracy: 0.9628
# Epoch 61/100
# 381/381 [==============================] - 0s 81us/sample - loss: 0.1597 - accuracy: 0.9659 - val_loss: 0.1423 - val_accuracy: 0.9628
# Epoch 62/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.1580 - accuracy: 0.9659 - val_loss: 0.1408 - val_accuracy: 0.9628
# Epoch 63/100
# 381/381 [==============================] - 0s 90us/sample - loss: 0.1564 - accuracy: 0.9633 - val_loss: 0.1394 - val_accuracy: 0.9734
# Epoch 64/100
# 381/381 [==============================] - 0s 93us/sample - loss: 0.1548 - accuracy: 0.9633 - val_loss: 0.1380 - val_accuracy: 0.9734
# Epoch 65/100
# 381/381 [==============================] - 0s 92us/sample - loss: 0.1533 - accuracy: 0.9633 - val_loss: 0.1366 - val_accuracy: 0.9734
# Epoch 66/100
# 381/381 [==============================] - 0s 83us/sample - loss: 0.1518 - accuracy: 0.9633 - val_loss: 0.1353 - val_accuracy: 0.9734
# Epoch 67/100
# 381/381 [==============================] - 0s 83us/sample - loss: 0.1503 - accuracy: 0.9633 - val_loss: 0.1340 - val_accuracy: 0.9734
# Epoch 68/100
# 381/381 [==============================] - 0s 80us/sample - loss: 0.1489 - accuracy: 0.9633 - val_loss: 0.1328 - val_accuracy: 0.9734
# Epoch 69/100
# 381/381 [==============================] - 0s 81us/sample - loss: 0.1476 - accuracy: 0.9633 - val_loss: 0.1317 - val_accuracy: 0.9734
# Epoch 70/100
# 381/381 [==============================] - 0s 87us/sample - loss: 0.1462 - accuracy: 0.9633 - val_loss: 0.1306 - val_accuracy: 0.9734
# Epoch 71/100
# 381/381 [==============================] - 0s 86us/sample - loss: 0.1449 - accuracy: 0.9633 - val_loss: 0.1294 - val_accuracy: 0.9734
# Epoch 72/100
# 381/381 [==============================] - 0s 87us/sample - loss: 0.1436 - accuracy: 0.9633 - val_loss: 0.1283 - val_accuracy: 0.9734
# Epoch 73/100
# 381/381 [==============================] - 0s 85us/sample - loss: 0.1424 - accuracy: 0.9633 - val_loss: 0.1272 - val_accuracy: 0.9734
# Epoch 74/100
# 381/381 [==============================] - 0s 84us/sample - loss: 0.1412 - accuracy: 0.9633 - val_loss: 0.1262 - val_accuracy: 0.9734
# Epoch 75/100
# 381/381 [==============================] - 0s 91us/sample - loss: 0.1400 - accuracy: 0.9633 - val_loss: 0.1252 - val_accuracy: 0.9734
# Epoch 76/100
# 381/381 [==============================] - 0s 98us/sample - loss: 0.1389 - accuracy: 0.9633 - val_loss: 0.1242 - val_accuracy: 0.9734
# Epoch 77/100
# 381/381 [==============================] - 0s 83us/sample - loss: 0.1378 - accuracy: 0.9633 - val_loss: 0.1232 - val_accuracy: 0.9734
# Epoch 78/100
# 381/381 [==============================] - 0s 79us/sample - loss: 0.1366 - accuracy: 0.9659 - val_loss: 0.1223 - val_accuracy: 0.9734
# Epoch 79/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.1356 - accuracy: 0.9659 - val_loss: 0.1214 - val_accuracy: 0.9734
# Epoch 80/100
# 381/381 [==============================] - 0s 92us/sample - loss: 0.1346 - accuracy: 0.9659 - val_loss: 0.1206 - val_accuracy: 0.9734
# Epoch 81/100
# 381/381 [==============================] - 0s 91us/sample - loss: 0.1335 - accuracy: 0.9659 - val_loss: 0.1197 - val_accuracy: 0.9787
# Epoch 82/100
# 381/381 [==============================] - 0s 95us/sample - loss: 0.1325 - accuracy: 0.9659 - val_loss: 0.1189 - val_accuracy: 0.9787
# Epoch 83/100
# 381/381 [==============================] - 0s 83us/sample - loss: 0.1316 - accuracy: 0.9659 - val_loss: 0.1181 - val_accuracy: 0.9787
# Epoch 84/100
# 381/381 [==============================] - 0s 79us/sample - loss: 0.1305 - accuracy: 0.9659 - val_loss: 0.1172 - val_accuracy: 0.9787
# Epoch 85/100
# 381/381 [==============================] - 0s 88us/sample - loss: 0.1296 - accuracy: 0.9659 - val_loss: 0.1165 - val_accuracy: 0.9787
# Epoch 86/100
# 381/381 [==============================] - 0s 77us/sample - loss: 0.1287 - accuracy: 0.9659 - val_loss: 0.1157 - val_accuracy: 0.9787
# Epoch 87/100
# 381/381 [==============================] - 0s 86us/sample - loss: 0.1278 - accuracy: 0.9659 - val_loss: 0.1149 - val_accuracy: 0.9787
# Epoch 88/100
# 381/381 [==============================] - 0s 82us/sample - loss: 0.1269 - accuracy: 0.9659 - val_loss: 0.1142 - val_accuracy: 0.9787
# Epoch 89/100
# 381/381 [==============================] - 0s 90us/sample - loss: 0.1261 - accuracy: 0.9659 - val_loss: 0.1134 - val_accuracy: 0.9787
# Epoch 90/100
# 381/381 [==============================] - 0s 79us/sample - loss: 0.1252 - accuracy: 0.9685 - val_loss: 0.1128 - val_accuracy: 0.9787
# Epoch 91/100
# 381/381 [==============================] - 0s 87us/sample - loss: 0.1244 - accuracy: 0.9685 - val_loss: 0.1121 - val_accuracy: 0.9787
# Epoch 92/100
# 381/381 [==============================] - 0s 78us/sample - loss: 0.1236 - accuracy: 0.9685 - val_loss: 0.1115 - val_accuracy: 0.9787
# Epoch 93/100
# 381/381 [==============================] - 0s 85us/sample - loss: 0.1228 - accuracy: 0.9685 - val_loss: 0.1108 - val_accuracy: 0.9787
# Epoch 94/100
# 381/381 [==============================] - 0s 91us/sample - loss: 0.1220 - accuracy: 0.9685 - val_loss: 0.1102 - val_accuracy: 0.9787
# Epoch 95/100
# 381/381 [==============================] - 0s 88us/sample - loss: 0.1212 - accuracy: 0.9685 - val_loss: 0.1095 - val_accuracy: 0.9787
# Epoch 96/100
# 381/381 [==============================] - 0s 96us/sample - loss: 0.1205 - accuracy: 0.9685 - val_loss: 0.1089 - val_accuracy: 0.9787
# Epoch 97/100
# 381/381 [==============================] - 0s 87us/sample - loss: 0.1198 - accuracy: 0.9711 - val_loss: 0.1084 - val_accuracy: 0.9787
# Epoch 98/100
# 381/381 [==============================] - 0s 90us/sample - loss: 0.1190 - accuracy: 0.9711 - val_loss: 0.1077 - val_accuracy: 0.9787
# Epoch 99/100
# 381/381 [==============================] - 0s 86us/sample - loss: 0.1183 - accuracy: 0.9711 - val_loss: 0.1072 - val_accuracy: 0.9787
# Epoch 100/100
# 381/381 [==============================] - 0s 88us/sample - loss: 0.1176 - accuracy: 0.9711 - val_loss: 0.1066 - val_accuracy: 0.9787
# 381/381 [==============================] - 0s 45us/sample - loss: 0.1172 - accuracy: 0.9711
# Train score:[0.11717324495667547, 0.9711286]
# 188/188 [==============================] - 0s 58us/sample - loss: 0.1066 - accuracy: 0.9787
# Test score: [0.10657680415092631, 0.9787234]

# %%
# Plot what's returned by model.fit()
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot the accuracy too
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %% [markdown]
# Make predictions

# %%
P = model.predict(X_test)
print(P[:8]) # they are outputs of the sigmoid, interpreted as probabilities p(y = 1 | x)
# Out:
# [[0.99584985]
#  [0.9974234 ]
#  [0.795103  ]
#  [0.9995523 ]
#  [0.98516476]
#  [0.00509803]
#  [0.99719846]
#  [0.9795821 ]]

# %%
# Round to get the actual predictions
# Note: has to be flattened since the targets are size (N,) while the predictions are size (N,1)
import numpy as np
P = np.round(P).flatten() #this is only valid of we asume that cut threshold is 0.5
print(P[:8])
# Out:
# [1. 1. 1. 1. 1. 0. 1. 1.]

# %%
# Calculate the accuracy, compare it to evaluate() output
print("Manually calculated accuracy:", np.mean(P == y_test))
print("Evaluate output:", model.evaluate(X_test, y_test))
# Out:
# Manually calculated accuracy: 0.9787234042553191
# 188/188 [==============================] - 0s 57us/sample - loss: 0.1066 - accuracy: 0.9787
# Evaluate output: [0.10657680415092631, 0.9787234]

# %%
# Saving the model 

# Let's now save our model to a file
model.save('linearclassifier.h5')

# %%
# Let's load the model and confirm that it still works
# Note: there is a bug in Keras where load/save only works if you DON'T use the Input() layer explicitly
# So, make sure you define the model with ONLY Dense(1, input_shape=(D,))
# At least, until the bug is fixed
# https://github.com/keras-team/keras/issues/10417
model = tf.keras.models.load_model('linearclassifier.h5')
print(model.layers)
model.evaluate(X_test, y_test)

# %%
# Download the file - requires Chrome (at this point)
from google.colab import files
files.download('linearclassifier.h5')
